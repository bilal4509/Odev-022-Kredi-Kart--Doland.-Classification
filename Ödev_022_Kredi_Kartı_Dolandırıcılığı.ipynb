# %% [markdown]
# <img src='11.jpg'>

# %%
#pip install pycaret

# %%
import pandas as pd

# %%
#Classification

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    id  Time        V1        V2        V3        V4        V5        V6  \
# 0   0   0.0  2.074329 -0.129425 -1.137418  0.412846 -0.192638 -1.210144
# 1   1   0.0  1.998827 -1.250891 -0.520969 -0.894539 -1.122528 -0.270866
# 2   2   0.0  0.091535  1.004517 -0.223445 -0.435249  0.667548 -0.988351
# 3   3   0.0  1.979649 -0.184949 -1.064206  0.120125 -0.215238 -0.648829
# 4   4   0.0  1.025898 -0.171827  1.203717  1.243900 -0.636572  1.099074
#
#          V7        V8  ...       V21       V22       V23       V24       V25  \
# 0  0.110697 -0.263477  ... -0.334701 -0.887840  0.336701 -0.110835 -0.291459
# 1 -1.029289  0.050198  ...  0.054848 -0.038367  0.133518 -0.461928 -0.465491
# 2  0.948146 -0.084789  ... -0.326725 -0.803736  0.154495  0.951233 -0.506919
# 3 -0.087826 -0.035367  ... -0.095514 -0.079792  0.167701 -0.042939  0.000799
# 4 -0.938651  0.569239  ...  0.099157  0.608908  0.027901 -0.262813  0.257834
#
#         V26       V27       V28  Amount  Class
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17635 entries, 0 to 17634
# Data columns (total 32 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      17635 non-null  int64
#  1   Time    17635 non-null  float64
#  2   V1      17635 non-null  float64
#  3   V2      17635 non-null  float64
#  4   V3      17635 non-null  float64
#  5   V4      17635 non-null  float64
#  6   V5      17635 non-null  float64
#  7   V6      17635 non-null  float64
#  8   V7      17635 non-null  float64
#  9   V8      17635 non-null  float64
#  10  V9      17635 non-null  float64
#  11  V10     17635 non-null  float64
#  12  V11     17635 non-null  float64
#  13  V12     17635 non-null  float64
#  14  V13     17635 non-null  float64
#  15  V14     17635 non-null  float64
#  16  V15     17635 non-null  float64
#  17  V16     17635 non-null  float64
#  18  V17     17634 non-null  float64
#  19  V18     17634 non-null  float64
# ...

# %%
from pycaret.classification import*

# %%
df = df.dropna(subset=['Class'])

# %%
setup(df,target='Class')
# Out:
# <style type="text/css">
# #T_7c70f_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7c70f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c70f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7c70f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c70f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c70f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7c70f_row0_col1" class="data row0 col1" >6321</td>
#     </tr>
#     <tr>
#       <th id="T_7c70f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c70f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7c70f_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_7c70f_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_f54f5 th {
#   text-align: left;
# }
# ...

# %%
best_model=create_model('knn')
# Out:
# <style type="text/css">
# #T_3821b_row10_col0, #T_3821b_row10_col1, #T_3821b_row10_col2, #T_3821b_row10_col3, #T_3821b_row10_col4, #T_3821b_row10_col5, #T_3821b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3821b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3821b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_3821b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_3821b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_3821b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_3821b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_3821b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_3821b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %% [raw]
# Banka kartı dolandırıcılığı, mağdurları için ciddi sonuçlar doğurabilecek mali bir suç türüdür. Bir banka kartı kullanıcısıysanız, banka kartı dolandırıcılığının ne olduğunu ve kendinizi bundan nasıl koruyacağınızı bilmeniz oldukça önemli.
#
# Banka kartı dolandırıcılığı nedir?
# Banka kartı dolandırıcılığı, birisi sizin izniniz olmadan banka kartınızı alışveriş yapmak veya hesabınızdan para çekmek için kullandığında meydana gelir. Bu, kimlik avı veya bir satıcının satış noktası sisteminin siber saldırılara maruz kalması gibi çeşitli şekillerde olabilir. Suçlular, kartınızı fiziksel olarak çalarak veya kart bilgilerinizi onlara vermeniz için sizi kandırarak da banka kartı bilgilerinizi çalabilir.
